# %%
import pandas as pd

df = pd.read_csv("Data/refined-real-estate.csv")
df
# Out:
#         Unnamed: 0  접수연도 자치구명 법정동명    본번  부번             건물명  물건금액(만원)  \
# 0                0  2025  도봉구  방학동   638  10    한신빌라(638-10)     14800
# 1                2  2025  강서구  등촌동   628  13          현대프린스텔     10300
# 2                3  2025  관악구  신림동  1639  51           푸리마타운     12700
# 3                4  2025  구로구  고척동   339   0        고척파크푸르지오     84000
# 4                5  2025  광진구  중곡동    73  70    욱현하이브(73-70)     19800
# ...            ...   ...  ...  ...   ...  ..             ...       ...
# 224571      235664  2022  송파구  거여동   234   0  e편한세상 송파 파크센트럴     69905
# 224572      235665  2022  강서구  방화동   186   3           마곡미라클     22500
# 224573      235667  2022  성북구  정릉동   260  10   진안빌라A(260-10)     35000
# 224574      235669  2022  성북구  정릉동   260  10   진안빌라A(260-10)     35000
# 224575      235670  2022  서초구  우면동    70   0             코오롱     42300
#
#         건물면적(㎡)   층  건축년도   건물용도  신고구분 신고한 개업공인중개사 시군구명  계약연도  계약월  계약일
# 0         37.66   4  1994  연립다세대  중개거래           서울 도봉구  2025    1   17
# 1         26.16   6  1999   오피스텔  중개거래           서울 강서구  2025    1   17
# 2         18.70   8  2014   오피스텔  중개거래           서울 관악구  2025    1   17
# 3         59.89   9  2009    아파트  중개거래   서울 구로구, 서울 양천구  2025    1   17
# 4         44.96   3  2009  연립다세대  중개거래           서울 동작구  2025    1   17
# ...         ...  ..   ...    ...   ...              ...   ...  ...  ...
# 224571    59.96  32     0    아파트  신고없음               없음  2018    1   24
# 224572    40.11   6  2017  연립다세대  신고없음               없음  2017    7   12
# 224573    57.95   2  1991  연립다세대  신고없음               없음  2016    6   20
# 224574    57.95   2  1991  연립다세대  신고없음               없음  2016    4   26
# 224575    52.47   6  1994    아파트  신고없음               없음  2013    1   23
#
# [224576 rows x 17 columns]

# %%
address_names = set()

for district_name, dong_name, main_number, sub_number in zip(
    df["자치구명"], df["법정동명"], df["본번"], df["부번"]
):
    address_name = (
        f"서울특별시 {district_name} {dong_name} {main_number}"
        if sub_number == 0
        else f"서울특별시 {district_name} {dong_name} {main_number}-{sub_number}"
    )
    address_names.add(address_name)
address_names, len(address_names)
# Out:
# ({'서울특별시 강동구 명일동 41',
#   '서울특별시 양천구 신정동 333',
#   '서울특별시 구로구 개봉동 261-10',
#   '서울특별시 강동구 길동 320-2',
#   '서울특별시 동작구 상도동 264-124',
#   '서울특별시 동대문구 용두동 39-860',
#   '서울특별시 종로구 동숭동 4-147',
#   '서울특별시 송파구 석촌동 175-12',
#   '서울특별시 마포구 망원동 435-37',
#   '서울특별시 금천구 시흥동 984-16',
#   '서울특별시 성북구 정릉동 206-67',
#   '서울특별시 영등포구 양평동1가 148-9',
#   '서울특별시 광진구 중곡동 85-1',
#   '서울특별시 도봉구 방학동 736',
#   '서울특별시 강동구 천호동 145-15',
#   '서울특별시 도봉구 방학동 608-57',
#   '서울특별시 강서구 화곡동 840-3',
#   '서울특별시 종로구 창신동 629-62',
#   '서울특별시 강남구 역삼동 747-5',
#   '서울특별시 은평구 대조동 48-2',
#   '서울특별시 강북구 우이동 5-5',
#   '서울특별시 도봉구 도봉동 566-15',
#   '서울특별시 중랑구 면목동 105-4',
#   '서울특별시 강동구 암사동 425-22',
#   '서울특별시 성북구 길음동 1285',
#   '서울특별시 서대문구 홍은동 277-123',
#   '서울특별시 관악구 신림동 1733',
#   '서울특별시 노원구 공릉동 758',
#   '서울특별시 서대문구 대현동 27-20',
#   '서울특별시 금천구 독산동 182-33',
#   '서울특별시 서대문구 연희동 100-3',
#   '서울특별시 마포구 합정동 386-10',
#   '서울특별시 양천구 신월동 71-22',
#   '서울특별시 서대문구 남가좌동 5-218',
#   '서울특별시 광진구 중곡동 296-27',
#   '서울특별시 강서구 화곡동 827-13',
#   '서울특별시 은평구 신사동 29-26',
#   '서울특별시 용산구 이촌동 426',
#   '서울특별시 서대문구 연희동 170-149',
#   '서울특별시 중랑구 면목동 66-76',
#   '서울특별시 강서구 화곡동 24-294',
#   '서울특별시 종로구 청운동 1',
#   '서울특별시 광진구 군자동 62-12',
#   '서울특별시 종로구 명륜1가 38-3',
#   '서울특별시 용산구 이태원동 206-12',
#   '서울특별시 은평구 역촌동 30-46',
#   '서울특별시 동작구 노량진동 84-34',
#   '서울특별시 서초구 방배동 462-21',
#   '서울특별시 구로구 고척동 220-15',
#   '서울특별시 도봉구 도봉동 62-3',
#   '서울특별시 강북구 미아동 791-3140',
#   '서울특별시 종로구 창신동 275',
#   '서울특별시 송파구 잠실동 200-11',
#   '서울특별시 성북구 정릉동 227-73',
#   '서울특별시 강북구 수유동 273-3',
#   '서울특별시 강동구 암사동 482-11',
#   '서울특별시 관악구 봉천동 1641-17',
#   '서울특별시 강남구 삼성동 93-4',
#   '서울특별시 은평구 갈현동 6-15',
#   '서울특별시 강서구 가양동 257-1',
#   '서울특별시 도봉구 도봉동 570-3',
#   '서울특별시 강동구 천호동 191-13',
#   '서울특별시 관악구 신림동 630-7',
#   '서울특별시 송파구 문정동 48-9',
#   '서울특별시 서대문구 연희동 613-5',
#   '서울특별시 송파구 삼전동 61-13',
#   '서울특별시 강서구 등촌동 515-3',
#   '서울특별시 광진구 중곡동 169-56',
#   '서울특별시 서대문구 연희동 163-13',
#   '서울특별시 구로구 개봉동 322-12',
#   '서울특별시 마포구 서교동 449-36',
#   '서울특별시 중랑구 중화동 301-70',
#   '서울특별시 중랑구 상봉동 84-39',
#   '서울특별시 성북구 정릉동 716-19',
#   '서울특별시 관악구 신림동 631-26',
#   '서울특별시 관악구 신림동 599-37',
#   '서울특별시 강북구 수유동 279-187',
#   '서울특별시 강북구 미아동 772-15',
#   '서울특별시 동대문구 장안동 431-7',
#   '서울특별시 강서구 가양동 448',
#   '서울특별시 강동구 길동 380-6',
#   '서울특별시 동작구 상도동 361-63',
#   '서울특별시 강서구 화곡동 24-340',
#   '서울특별시 마포구 노고산동 20-75',
#   '서울특별시 마포구 신수동 429-14',
#   '서울특별시 서대문구 대현동 90-22',
#   '서울특별시 종로구 연건동 43-1',
#   '서울특별시 양천구 신정동 876-2',
#   '서울특별시 강북구 번동 148-344',
#   '서울특별시 송파구 삼전동 52-8',
#   '서울특별시 강동구 암사동 500-14',
#   '서울특별시 중랑구 망우동 343-2',
#   '서울특별시 광진구 중곡동 169-110',
#   '서울특별시 구로구 구로동 317-31',
#   '서울특별시 송파구 삼전동 99-4',
#   '서울특별시 은평구 응암동 120-13',
#   '서울특별시 영등포구 대림동 1112',
#   '서울특별시 관악구 신림동 412-180',
#   '서울특별시 송파구 삼전동 57-8',
#   '서울특별시 금천구 독산동 292-2',
#   '서울특별시 동작구 대방동 13-38',
#   '서울특별시 강동구 성내동 226-53',
#   '서울특별시 영등포구 양평동4가 94',
#   '서울특별시 광진구 자양동 689-7',
#   '서울특별시 강서구 화곡동 160-3',
#   '서울특별시 강동구 성내동 434-4',
#   '서울특별시 양천구 신월동 479-6',
#   '서울특별시 도봉구 창동 603-87',
#   '서울특별시 동대문구 휘경동 28-19',
#   '서울특별시 광진구 중곡동 141-26',
#   '서울특별시 은평구 역촌동 45-30',
#   '서울특별시 강북구 수유동 486-61',
#   '서울특별시 동작구 대방동 335-26',
#   '서울특별시 양천구 신월동 488-16',
#   '서울특별시 금천구 가산동 235-13',
#   '서울특별시 서대문구 북가좌동 3-131',
#   '서울특별시 강서구 등촌동 518-18',
#   '서울특별시 강북구 미아동 323-36',
#   '서울특별시 동작구 사당동 316-258',
#   '서울특별시 관악구 봉천동 635-351',
#   '서울특별시 송파구 문정동 65-15',
#   '서울특별시 송파구 삼전동 67-5',
#   '서울특별시 강동구 둔촌동 61-9',
#   '서울특별시 동작구 노량진동 232-275',
#   '서울특별시 영등포구 대림동 926-6',
#   '서울특별시 중랑구 망우동 580',
#   '서울특별시 송파구 가락동 129-6',
#   '서울특별시 관악구 신림동 1630-10',
#   '서울특별시 관악구 신림동 610-575',
#   '서울특별시 은평구 갈현동 110-13',
#   '서울특별시 강북구 수유동 252-44',
#   '서울특별시 광진구 자양동 227-109',
#   '서울특별시 양천구 신월동 526-6',
#   '서울특별시 강남구 청담동 59-2',
#   '서울특별시 동대문구 용두동 20-54',
#   '서울특별시 금천구 가산동 238-78',
#   '서울특별시 강북구 수유동 178-14',
#   '서울특별시 동대문구 장안동 295-3',
#   '서울특별시 서초구 방배동 829-13',
#   '서울특별시 성북구 삼선동3가 99-2',
#   '서울특별시 용산구 후암동 30-99',
#   '서울특별시 강서구 방화동 611-125',
#   '서울특별시 양천구 목동 531-3',
#   '서울특별시 마포구 망원동 396-47',
#   '서울특별시 중랑구 중화동 321-65',
#   '서울특별시 성동구 성수동1가 718',
#   '서울특별시 마포구 성산동 50-25',
#   '서울특별시 강동구 천호동 289-44',
#   '서울특별시 관악구 신림동 610-127',
#   '서울특별시 구로구 고척동 167-91',
#   '서울특별시 용산구 청파동1가 1-3',
#   '서울특별시 송파구 방이동 165',
#   '서울특별시 동작구 상도동 211-371',
#   '서울특별시 금천구 시흥동 1008',
#   '서울특별시 송파구 방이동 212-4',
#   '서울특별시 도봉구 도봉동 626-117',
#   '서울특별시 강북구 수유동 714-1',
#   '서울특별시 종로구 평창동 523-9',
#   '서울특별시 은평구 역촌동 67-26',
#   '서울특별시 광진구 자양동 667-19',
#   '서울특별시 은평구 갈현동 18-3',
#   '서울특별시 도봉구 방학동 685-60',
#   '서울특별시 용산구 신계동 8-15',
#   '서울특별시 영등포구 당산동5가 7-2',
#   '서울특별시 은평구 응암동 72-4',
#   '서울특별시 서초구 방배동 480-14',
#   '서울특별시 용산구 용산동3가 6-10',
#   '서울특별시 서초구 양재동 272-2',
#   '서울특별시 도봉구 방학동 632-23',
#   '서울특별시 도봉구 방학동 684-33',
#   '서울특별시 은평구 응암동 95-17',
#   '서울특별시 도봉구 쌍문동 495-36',
#   '서울특별시 도봉구 방학동 636-1',
#   '서울특별시 강서구 화곡동 24-113',
#   '서울특별시 광진구 자양동 664-12',
#   '서울특별시 마포구 염리동 85-21',
#   '서울특별시 용산구 이태원동 151-27',
#   '서울특별시 은평구 역촌동 37-48',
#   '서울특별시 송파구 삼전동 66-18',
#   '서울특별시 마포구 연남동 487-47',
#   '서울특별시 강서구 화곡동 455-9',
#   '서울특별시 은평구 대조동 84-17',
#   '서울특별시 관악구 신림동 534-1',
#   '서울특별시 강남구 도곡동 91-5',
#   '서울특별시 강서구 화곡동 918-1',
#   '서울특별시 강북구 미아동 223-4',
#   '서울특별시 중랑구 면목동 353-55',
#   '서울특별시 강서구 공항동 1374',
#   '서울특별시 중랑구 면목동 653-3',
#   '서울특별시 강서구 방화동 493-17',
#   '서울특별시 도봉구 도봉동 616-10',
#   '서울특별시 성북구 안암동2가 113-2',
#   '서울특별시 서초구 서초동 1588-1',
#   '서울특별시 영등포구 대림동 1066-74',
#   '서울특별시 양천구 신정동 913-2',
#   '서울특별시 강북구 수유동 524-76',
#   '서울특별시 종로구 평창동 66-25',
#   '서울특별시 마포구 노고산동 19-17',
#   '서울특별시 광진구 화양동 527',
#   '서울특별시 성북구 안암동3가 135',
#   '서울특별시 서대문구 남가좌동 64-18',
#   '서울특별시 관악구 신림동 1481-3',
#   '서울특별시 금천구 독산동 332-16',
#   '서울특별시 강서구 화곡동 368-36',
#   '서울특별시 금천구 시흥동 934-4',
#   '서울특별시 성동구 행당동 345',
#   '서울특별시 중랑구 중화동 327-102',
#   '서울특별시 영등포구 당산동3가 559',
#   '서울특별시 관악구 신림동 545-37',
#   '서울특별시 서초구 반포동 69-1',
#   '서울특별시 강서구 화곡동 355-19',
#   '서울특별시 강동구 암사동 450-10',
#   '서울특별시 도봉구 쌍문동 220-7',
#   '서울특별시 은평구 응암동 584-16',
#   '서울특별시 강서구 방화동 645-34',
#   '서울특별시 금천구 시흥동 219-16',
#   '서울특별시 은평구 갈현동 259-18',
#   '서울특별시 도봉구 창동 608-56',
#   '서울특별시 용산구 갈월동 5-61',
#   '서울특별시 광진구 자양동 227-122',
#   '서울특별시 강서구 내발산동 710-54',
#   '서울특별시 광진구 중곡동 73-71',
#   '서울특별시 동대문구 신설동 8-1',
#   '서울특별시 성북구 정릉동 431-70',
#   '서울특별시 송파구 방이동 132',
#   '서울특별시 동대문구 장안동 350-6',
#   '서울특별시 은평구 신사동 6-15',
#   '서울특별시 양천구 신월동 98-24',
#   '서울특별시 강남구 논현동 103-1',
#   '서울특별시 은평구 응암동 123-6',
#   '서울특별시 은평구 대조동 87-7',
#   '서울특별시 양천구 신월동 217-44',
#   '서울특별시 마포구 망원동 438-7',
#   '서울특별시 강북구 미아동 324-9',
#   '서울특별시 노원구 중계동 366',
#   '서울특별시 송파구 방이동 193-37',
#   '서울특별시 강서구 화곡동 971-8',
#   '서울특별시 강서구 화곡동 351-20',
#   '서울특별시 은평구 응암동 376-18',
#   '서울특별시 중랑구 묵동 176-9',
#   '서울특별시 송파구 송파동 18-6',
#   '서울특별시 강서구 화곡동 111-27',
#   '서울특별시 강동구 암사동 474-41',
#   '서울특별시 강북구 수유동 270-104',
#   '서울특별시 용산구 후암동 406-7',
#   '서울특별시 은평구 갈현동 515-23',
#   '서울특별시 강서구 화곡동 1113-22',
#   '서울특별시 성북구 정릉동 266-557',
#   '서울특별시 강북구 번동 471-150',
#   '서울특별시 용산구 효창동 5-88',
#   '서울특별시 강서구 내발산동 698-12',
#   '서울특별시 송파구 송파동 147-16',
#   '서울특별시 구로구 항동 242',
#   '서울특별시 동작구 흑석동 200-8',
#   '서울특별시 중랑구 상봉동 87-52',
#   '서울특별시 금천구 독산동 905-36',
#   '서울특별시 송파구 석촌동 288-17',
#   '서울특별시 은평구 갈현동 521-2',
#   '서울특별시 종로구 숭인동 535',
#   '서울특별시 관악구 봉천동 645-121',
#   '서울특별시 관악구 봉천동 1691-29',
#   '서울특별시 성동구 홍익동 125-1',
#   '서울특별시 중랑구 면목동 410-8',
#   '서울특별시 송파구 마천동 17-1',
#   '서울특별시 종로구 부암동 123-5',
#   '서울특별시 강북구 수유동 57-113',
#   '서울특별시 송파구 마천동 322-6',
#   '서울특별시 강서구 화곡동 59-75',
#   '서울특별시 용산구 용산동2가 1-1611',
#   '서울특별시 성북구 돈암동 39-8',
#   '서울특별시 강서구 등촌동 514-30',
#   '서울특별시 금천구 독산동 234-35',
#   '서울특별시 마포구 망원동 456-42',
#   '서울특별시 은평구 역촌동 18-19',
#   '서울특별시 금천구 시흥동 840-31',
#   '서울특별시 종로구 홍지동 35-3',
#   '서울특별시 강서구 마곡동 751',
#   '서울특별시 구로구 개봉동 139-89',
#   '서울특별시 강남구 청담동 15-21',
#   '서울특별시 구로구 개봉동 279-5',
#   '서울특별시 송파구 가락동 15-6',
#   '서울특별시 강남구 개포동 1215-6',
#   '서울특별시 중랑구 중화동 100-3',
#   '서울특별시 관악구 봉천동 1653-18',
#   '서울특별시 강동구 길동 349-10',
#   '서울특별시 중랑구 면목동 88-72',
#   '서울특별시 관악구 봉천동 1510-34',
#   '서울특별시 관악구 신림동 652-93',
#   '서울특별시 은평구 응암동 104-38',
#   '서울특별시 구로구 개봉동 23-22',
#   '서울특별시 서초구 반포동 727-2',
#   '서울특별시 중랑구 묵동 248-126',
#   '서울특별시 중구 신당동 366-314',
#   '서울특별시 구로구 구로동 806-14',
#   '서울특별시 용산구 문배동 24-8',
#   '서울특별시 강서구 화곡동 805-17',
#   '서울특별시 관악구 봉천동 14-119',
#   '서울특별시 강동구 천호동 287-9',
#   '서울특별시 중구 신당동 432-397',
#   '서울특별시 동작구 대방동 393-31',
#   '서울특별시 동작구 사당동 178-23',
#   '서울특별시 중랑구 묵동 122-103',
#   '서울특별시 서대문구 홍제동 312-221',
#   '서울특별시 동대문구 이문동 427',
#   '서울특별시 광진구 중곡동 53-19',
#   '서울특별시 관악구 봉천동 635-27',
#   '서울특별시 강서구 염창동 272-20',
#   '서울특별시 강남구 청담동 121-61',
#   '서울특별시 도봉구 방학동 422-1',
#   '서울특별시 강북구 미아동 350-2',
#   '서울특별시 관악구 신림동 610-335',
#   '서울특별시 강서구 화곡동 425-5',
#   '서울특별시 도봉구 쌍문동 460-72',
#   '서울특별시 영등포구 문래동1가 22-12',
#   '서울특별시 은평구 응암동 71-9',
#   '서울특별시 양천구 신월동 467-3',
#   '서울특별시 서대문구 연희동 446-246',
#   '서울특별시 강북구 수유동 172-104',
#   '서울특별시 송파구 장지동 849',
#   '서울특별시 강서구 화곡동 56-322',
#   '서울특별시 광진구 구의동 51-13',
#   '서울특별시 중랑구 면목동 375-10',
#   '서울특별시 송파구 석촌동 274-4',
#   '서울특별시 종로구 내수동 75',
#   '서울특별시 은평구 구산동 368-51',
#   '서울특별시 관악구 봉천동 673-82',
#   '서울특별시 성북구 돈암동 580-9',
#   '서울특별시 서초구 반포동 730-1',
#   '서울특별시 강서구 가양동 146-8',
#   '서울특별시 은평구 갈현동 493-11',
#   '서울특별시 강서구 화곡동 362-55',
#   '서울특별시 서대문구 북아현동 129-75',
#   '서울특별시 송파구 오금동 133-16',
#   '서울특별시 동작구 사당동 193-5',
#   '서울특별시 은평구 신사동 34-7',
#   '서울특별시 도봉구 방학동 685-34',
#   '서울특별시 용산구 동자동 45',
#   '서울특별시 은평구 응암동 113-28',
#   '서울특별시 서초구 서초동 1642-34',
#   '서울특별시 광진구 구의동 647-7',
#   '서울특별시 광진구 중곡동 168-1',
#   '서울특별시 서초구 반포동 757',
#   '서울특별시 동대문구 장안동 146-18',
#   '서울특별시 구로구 개봉동 23-31',
#   '서울특별시 은평구 신사동 39-19',
#   '서울특별시 은평구 대조동 89-258',
#   '서울특별시 양천구 신월동 49-2',
#   '서울특별시 강남구 개포동 1167',
#   '서울특별시 강북구 수유동 52-65',
#   '서울특별시 은평구 불광동 245-38',
#   '서울특별시 강북구 수유동 412-7',
#   '서울특별시 광진구 중곡동 91-4',
#   '서울특별시 구로구 개봉동 363-6',
#   '서울특별시 은평구 신사동 26-35',
#   '서울특별시 은평구 갈현동 425-16',
#   '서울특별시 성북구 정릉동 227-88',
#   '서울특별시 노원구 월계동 951',
#   '서울특별시 강동구 암사동 447-8',
#   '서울특별시 관악구 신림동 612-24',
#   '서울특별시 강북구 수유동 510-1',
#   '서울특별시 서대문구 홍은동 265-230',
#   '서울특별시 구로구 구로동 486-69',
#   '서울특별시 동작구 사당동 446-146',
#   '서울특별시 서초구 방배동 530-31',
#   '서울특별시 도봉구 방학동 659-34',
#   '서울특별시 강동구 성내동 447-2',
#   '서울특별시 강서구 화곡동 396-9',
#   '서울특별시 중랑구 면목동 99-19',
#   '서울특별시 송파구 방이동 100-17',
#   '서울특별시 영등포구 대림동 946-1',
#   '서울특별시 광진구 광장동 184-11',
#   '서울특별시 은평구 갈현동 479-13',
#   '서울특별시 도봉구 방학동 612-25',
#   '서울특별시 송파구 방이동 225',
#   '서울특별시 성북구 성북동 145-52',
#   '서울특별시 동대문구 답십리동 494-1',
#   '서울특별시 종로구 누상동 166-247',
#   '서울특별시 광진구 구의동 670',
#   '서울특별시 금천구 시흥동 992-22',
#   '서울특별시 은평구 녹번동 86-126',
#   '서울특별시 마포구 합정동 198-6',
#   '서울특별시 관악구 봉천동 173-30',
#   '서울특별시 은평구 신사동 1-51',
#   '서울특별시 금천구 시흥동 3-215',
#   '서울특별시 서대문구 북가좌동 5-114',
#   '서울특별시 성북구 장위동 246-375',
#   '서울특별시 송파구 잠실동 212-41',
#   '서울특별시 광진구 화양동 2-22',
#   '서울특별시 성동구 마장동 778-4',
#   '서울특별시 마포구 창전동 149-1',
#   '서울특별시 강북구 미아동 223-29',
#   '서울특별시 노원구 월계동 13',
#   '서울특별시 강북구 수유동 546-3',
#   '서울특별시 금천구 독산동 974-1',
#   '서울특별시 동작구 상도동 299-17',
#   '서울특별시 강서구 화곡동 1046-12',
#   '서울특별시 은평구 역촌동 26-22',
#   '서울특별시 강남구 역삼동 636-33',
#   '서울특별시 강서구 화곡동 24-46',
#   '서울특별시 관악구 신림동 1716',
#   '서울특별시 양천구 신정동 942-17',
#   '서울특별시 강북구 수유동 52-49',
#   '서울특별시 강동구 성내동 417-20',
#   '서울특별시 중랑구 상봉동 496',
#   '서울특별시 마포구 대흥동 18-84',
#   '서울특별시 관악구 봉천동 63-45',
#   '서울특별시 서대문구 북가좌동 310-1',
#   '서울특별시 은평구 녹번동 82-32',
#   '서울특별시 마포구 망원동 396-1',
#   '서울특별시 은평구 대조동 214-16',
#   '서울특별시 구로구 궁동 89-4',
#   '서울특별시 마포구 아현동 738',
#   '서울특별시 강북구 수유동 296-5',
#   '서울특별시 강서구 화곡동 341-49',
#   '서울특별시 중랑구 상봉동 315-40',
#   '서울특별시 강남구 개포동 1198-4',
#   '서울특별시 종로구 누상동 166-3',
#   '서울특별시 성북구 종암동 32-6',
#   '서울특별시 성북구 하월곡동 90-1228',
#   '서울특별시 강서구 화곡동 974-10',
#   '서울특별시 동작구 사당동 141-234',
#   '서울특별시 송파구 석촌동 240-9',
#   '서울특별시 광진구 중곡동 141-29',
#   '서울특별시 은평구 대조동 50-32',
#   '서울특별시 동작구 동작동 333',
#   '서울특별시 마포구 중동 109',
#   '서울특별시 용산구 한남동 647-47',
#   '서울특별시 송파구 마천동 40-10',
#   '서울특별시 강남구 삼성동 127-5',
#   '서울특별시 마포구 성산동 630-11',
#   '서울특별시 강남구 개포동 1263-8',
#   '서울특별시 중랑구 상봉동 120-46',
#   '서울특별시 광진구 자양동 640-31',
#   '서울특별시 강서구 내발산동 687-13',
#   '서울특별시 서초구 방배동 889-15',
#   '서울특별시 강서구 화곡동 399-2',
#   '서울특별시 은평구 불광동 530',
#   '서울특별시 동대문구 장안동 575',
#   '서울특별시 동대문구 장안동 578',
#   '서울특별시 서초구 양재동 7-6',
#   '서울특별시 은평구 구산동 308-27',
#   '서울특별시 용산구 이촌동 203-14',
#   '서울특별시 구로구 구로동 801-29',
#   '서울특별시 성북구 정릉동 716-21',
#   '서울특별시 도봉구 창동 809',
#   '서울특별시 마포구 노고산동 19-66',
#   '서울특별시 강서구 화곡동 29-221',
#   '서울특별시 양천구 신월동 482-19',
#   '서울특별시 서초구 방배동 333-4',
#   '서울특별시 강동구 천호동 22-11',
#   '서울특별시 은평구 역촌동 4-19',
#   '서울특별시 은평구 신사동 228-15',
#   '서울특별시 강남구 역삼동 782-29',
#   '서울특별시 양천구 신정동 950-4',
#   '서울특별시 동작구 사당동 278-71',
#   '서울특별시 중구 장충동1가 50-1',
#   '서울특별시 성북구 삼선동3가 116',
#   '서울특별시 구로구 구로동 748-32',
#   '서울특별시 송파구 풍납동 151-28',
#   '서울특별시 강서구 화곡동 157-17',
#   '서울특별시 종로구 효제동 126-2',
#   '서울특별시 서대문구 북가좌동 290-12',
#   '서울특별시 관악구 신림동 316-62',
#   '서울특별시 서대문구 북아현동 1009',
#   '서울특별시 광진구 중곡동 288-7',
#   '서울특별시 양천구 목동 804-4',
#   '서울특별시 은평구 불광동 444-12',
#   '서울특별시 은평구 갈현동 275-14',
#   '서울특별시 종로구 신영동 233',
#   '서울특별시 강서구 방화동 612-71',
#   '서울특별시 강서구 화곡동 370-20',
#   '서울특별시 서초구 서초동 1494-1',
#   '서울특별시 강서구 화곡동 357-21',
#   '서울특별시 강북구 수유동 468-39',
#   '서울특별시 강서구 등촌동 637-28',
#   '서울특별시 은평구 녹번동 152-59',
#   '서울특별시 동작구 상도동 214-134',
#   '서울특별시 용산구 한남동 616-2',
#   '서울특별시 강남구 논현동 244-9',
#   '서울특별시 금천구 시흥동 960-12',
#   '서울특별시 강북구 수유동 475-116',
#   '서울특별시 강서구 화곡동 55-92',
#   '서울특별시 강북구 우이동 6-6',
#   '서울특별시 금천구 시흥동 959-8',
#   '서울특별시 관악구 신림동 11-8',
#   '서울특별시 관악구 봉천동 661-45',
#   '서울특별시 강서구 화곡동 102-344',
#   '서울특별시 은평구 진관동 92',
#   '서울특별시 도봉구 쌍문동 531-10',
#   '서울특별시 관악구 신림동 1667-14',
#   '서울특별시 강서구 화곡동 379-28',
#   '서울특별시 은평구 역촌동 59-15',
#   '서울특별시 강서구 화곡동 748-24',
#   '서울특별시 은평구 응암동 227-17',
#   '서울특별시 중랑구 상봉동 104-84',
#   '서울특별시 구로구 고척동 145-77',
#   '서울특별시 양천구 목동 521-33',
#   '서울특별시 강동구 천호동 167-54',
#   '서울특별시 관악구 신림동 458-9',
#   '서울특별시 관악구 신림동 763-61',
#   '서울특별시 성북구 석관동 178-4',
#   '서울특별시 강북구 수유동 738',
#   '서울특별시 종로구 창신동 23-606',
#   '서울특별시 관악구 신림동 511-14',
#   '서울특별시 노원구 하계동 167-10',
#   '서울특별시 금천구 시흥동 960-6',
#   '서울특별시 강서구 화곡동 56-103',
#   '서울특별시 양천구 신월동 200-5',
#   '서울특별시 강동구 암사동 497-6',
#   '서울특별시 송파구 석촌동 60-7',
#   '서울특별시 강서구 화곡동 456-21',
#   '서울특별시 송파구 오금동 131-9',
#   '서울특별시 중랑구 상봉동 315-68',
#   '서울특별시 도봉구 도봉동 587-1',
#   '서울특별시 관악구 봉천동 952-14',
#   '서울특별시 용산구 청파동3가 108-5',
#   '서울특별시 강동구 길동 392-9',
#   '서울특별시 용산구 한강로3가 91',
#   '서울특별시 양천구 신정동 876-17',
#   '서울특별시 강서구 화곡동 824-9',
#   '서울특별시 서대문구 북가좌동 312-32',
#   '서울특별시 구로구 구로동 743-37',
#   '서울특별시 강동구 천호동 195-19',
#   '서울특별시 관악구 신림동 474-7',
#   '서울특별시 강서구 내발산동 717-3',
#   '서울특별시 성동구 송정동 104',
#   '서울특별시 관악구 신림동 251-58',
#   '서울특별시 관악구 신림동 570-7',
#   '서울특별시 강동구 천호동 46-11',
#   '서울특별시 마포구 망원동 513',
#   '서울특별시 서초구 잠원동 65-32',
#   '서울특별시 강서구 방화동 885',
#   '서울특별시 서대문구 북아현동 3-211',
#   '서울특별시 서대문구 충정로3가 1-37',
#   '서울특별시 서초구 양재동 7-47',
#   '서울특별시 은평구 응암동 100-54',
#   '서울특별시 은평구 신사동 1-12',
#   '서울특별시 서초구 반포동 48-2',
#   '서울특별시 강남구 삼성동 125-2',
#   '서울특별시 강서구 화곡동 914-32',
#   '서울특별시 광진구 중곡동 247-21',
#   '서울특별시 강서구 화곡동 423-15',
#   '서울특별시 서초구 반포동 30-26',
#   '서울특별시 마포구 망원동 505',
#   '서울특별시 종로구 누상동 166-7',
#   '서울특별시 금천구 가산동 535-55',
#   '서울특별시 강북구 수유동 482-20',
#   '서울특별시 영등포구 영등포동7가 64-54',
#   '서울특별시 강북구 미아동 258-556',
#   '서울특별시 동작구 노량진동 234-5',
#   '서울특별시 관악구 신림동 610-162',
#   '서울특별시 송파구 마천동 576',
#   '서울특별시 은평구 갈현동 518-1',
#   '서울특별시 관악구 봉천동 870-12',
#   '서울특별시 강서구 화곡동 42-46',
#   '서울특별시 중랑구 상봉동 101-30',
#   '서울특별시 관악구 신림동 607-43',
#   '서울특별시 동작구 사당동 1037-9',
#   '서울특별시 강서구 등촌동 517-21',
#   '서울특별시 양천구 목동 318-238',
#   '서울특별시 도봉구 방학동 732',
#   '서울특별시 관악구 신림동 1421-1',
#   '서울특별시 구로구 개봉동 313-33',
#   '서울특별시 강북구 번동 348-9',
#   '서울특별시 서대문구 홍은동 189-33',
#   '서울특별시 성동구 금호동2가 508-1',
#   '서울특별시 서대문구 홍제동 322-134',
#   '서울특별시 강서구 화곡동 1014-9',
#   '서울특별시 구로구 신도림동 695',
#   '서울특별시 은평구 갈현동 275-19',
#   '서울특별시 강서구 방화동 819',
#   '서울특별시 양천구 신월동 112-17',
#   '서울특별시 구로구 가리봉동 121-33',
#   '서울특별시 동대문구 장안동 466-4',
#   '서울특별시 도봉구 도봉동 574-2',
#   '서울특별시 도봉구 창동 608-184',
#   '서울특별시 동작구 사당동 1051-28',
#   '서울특별시 동작구 신대방동 341-178',
#   '서울특별시 관악구 신림동 92-187',
#   '서울특별시 강동구 성내동 245',
#   '서울특별시 강동구 성내동 465-4',
#   '서울특별시 강북구 번동 136',
#   '서울특별시 관악구 봉천동 1630-7',
#   '서울특별시 은평구 녹번동 108-7',
#   '서울특별시 동작구 상도동 126-8',
#   '서울특별시 도봉구 창동 647-1',
#   '서울특별시 은평구 역촌동 25-38',
#   '서울특별시 은평구 녹번동 91-9',
#   '서울특별시 은평구 갈현동 275-63',
#   '서울특별시 동작구 신대방동 364-200',
#   '서울특별시 송파구 거여동 13-26',
#   '서울특별시 동작구 대방동 391-567',
#   '서울특별시 도봉구 창동 296-11',
#   '서울특별시 동작구 신대방동 599-33',
#   '서울특별시 마포구 망원동 485-39',
#   '서울특별시 강서구 화곡동 1054-2',
#   '서울특별시 광진구 자양동 658-8',
#   '서울특별시 중구 신당동 333-40',
#   '서울특별시 종로구 누상동 112-1',
#   '서울특별시 강북구 수유동 733',
#   '서울특별시 중랑구 면목동 1516',
#   '서울특별시 송파구 문정동 82-14',
#   '서울특별시 광진구 중곡동 210-12',
#   '서울특별시 강서구 화곡동 458-24',
#   '서울특별시 강남구 대치동 982-4',
#   '서울특별시 서초구 방배동 460-6',
#   '서울특별시 서초구 방배동 766-26',
#   '서울특별시 중랑구 망우동 514-5',
#   '서울특별시 송파구 문정동 116-11',
#   '서울특별시 중랑구 상봉동 313-10',
#   '서울특별시 강서구 화곡동 350-26',
#   '서울특별시 은평구 역촌동 43-40',
#   '서울특별시 양천구 목동 733-12',
#   '서울특별시 중랑구 면목동 1375',
#   '서울특별시 강서구 등촌동 514-34',
#   '서울특별시 성북구 안암동2가 160-23',
#   '서울특별시 은평구 갈현동 271',
#   '서울특별시 용산구 용문동 38-186',
#   '서울특별시 은평구 역촌동 34-23',
#   '서울특별시 은평구 역촌동 36-3',
#   '서울특별시 금천구 독산동 957-1',
#   '서울특별시 구로구 구로동 685-70',
#   '서울특별시 관악구 신림동 1505-4',
#   '서울특별시 동작구 상도동 201-133',
#   '서울특별시 강남구 일원동 664',
#   '서울특별시 중구 신당동 113-3',
#   '서울특별시 강서구 공항동 683-14',
#   '서울특별시 강동구 성내동 464-16',
#   '서울특별시 강북구 수유동 569-52',
#   '서울특별시 영등포구 대림동 737-11',
#   '서울특별시 관악구 신림동 1563-24',
#   '서울특별시 서대문구 북가좌동 5-24',
#   '서울특별시 중랑구 중화동 131-34',
#   '서울특별시 동대문구 답십리동 467-40',
#   '서울특별시 관악구 봉천동 100-89',
#   '서울특별시 강서구 화곡동 962-6',
#   '서울특별시 동작구 상도동 356-146',
#   '서울특별시 관악구 신림동 610-188',
#   '서울특별시 동대문구 휘경동 366',
#   '서울특별시 송파구 거여동 178-6',
#   '서울특별시 송파구 오금동 52-15',
#   '서울특별시 강동구 성내동 208-2',
#   '서울특별시 마포구 망원동 399-11',
#   '서울특별시 관악구 봉천동 649-104',
#   '서울특별시 금천구 독산동 934-2',
#   '서울특별시 양천구 신월동 88-28',
#   '서울특별시 은평구 응암동 89-12',
#   '서울특별시 중구 신당동 333-9',
#   '서울특별시 성동구 성수동2가 321-107',
#   '서울특별시 강동구 성내동 174-32',
#   '서울특별시 강동구 상일동 297-10',
#   '서울특별시 중랑구 면목동 365-1',
#   '서울특별시 은평구 구산동 224',
#   '서울특별시 강북구 수유동 522-47',
#   '서울특별시 양천구 신월동 413-5',
#   '서울특별시 구로구 궁동 210-13',
#   '서울특별시 강서구 화곡동 341-6',
#   '서울특별시 광진구 자양동 611-2',
#   '서울특별시 강서구 염창동 287-1',
#   '서울특별시 동대문구 청량리동 199',
#   '서울특별시 은평구 역촌동 70-28',
#   '서울특별시 강서구 염창동 264-40',
#   '서울특별시 송파구 마천동 47-2',
#   '서울특별시 용산구 원효로3가 240-1',
#   '서울특별시 양천구 신월동 443-4',
#   '서울특별시 도봉구 도봉동 573-15',
#   '서울특별시 강서구 화곡동 786-15',
#   '서울특별시 도봉구 쌍문동 137-187',
#   '서울특별시 강동구 천호동 204',
#   '서울특별시 용산구 용산동2가 22-5',
#   '서울특별시 동작구 상도동 279-386',
#   '서울특별시 강남구 개포동 1182-4',
#   '서울특별시 노원구 상계동 1380-1',
#   '서울특별시 양천구 신월동 942-6',
#   '서울특별시 용산구 효창동 5-110',
#   '서울특별시 금천구 시흥동 3-99',
#   '서울특별시 서대문구 북가좌동 336-9',
#   '서울특별시 성동구 응봉동 265-133',
#   '서울특별시 은평구 대조동 5-11',
#   '서울특별시 동작구 사당동 316-102',
#   '서울특별시 은평구 역촌동 57-5',
#   '서울특별시 양천구 신월동 52-13',
#   '서울특별시 관악구 신림동 611-171',
#   '서울특별시 강동구 천호동 34-14',
#   '서울특별시 마포구 망원동 404-33',
#   '서울특별시 은평구 응암동 121-30',
#   '서울특별시 영등포구 여의도동 55-1',
#   '서울특별시 은평구 녹번동 156-25',
#   '서울특별시 성북구 하월곡동 46-73',
#   '서울특별시 마포구 서교동 475-17',
#   '서울특별시 광진구 구의동 552-2',
#   '서울특별시 양천구 신월동 201-20',
#   '서울특별시 도봉구 쌍문동 74-7',
#   '서울특별시 강동구 천호동 233-51',
#   '서울특별시 노원구 공릉동 743',
#   '서울특별시 강동구 성내동 386-14',
#   '서울특별시 도봉구 방학동 650-30',
#   '서울특별시 금천구 가산동 234-26',
#   '서울특별시 동작구 상도동 210-188',
#   '서울특별시 동작구 상도동 210-9',
#   '서울특별시 서초구 방배동 922-15',
#   '서울특별시 마포구 창전동 6-160',
#   '서울특별시 은평구 갈현동 526-3',
#   '서울특별시 강서구 화곡동 379-82',
#   '서울특별시 강남구 역삼동 747',
#   '서울특별시 은평구 역촌동 8-34',
#   '서울특별시 관악구 봉천동 1709-1',
#   '서울특별시 영등포구 문래동3가 93-1',
#   '서울특별시 강남구 개포동 1235-4',
#   '서울특별시 종로구 혜화동 10-7',
#   '서울특별시 중랑구 중화동 320-102',
#   '서울특별시 양천구 신월동 10-7',
#   '서울특별시 강북구 미아동 3-9',
#   '서울특별시 금천구 독산동 201-2',
#   '서울특별시 영등포구 도림동 234-1',
#   '서울특별시 영등포구 양평동3가 3-1',
#   '서울특별시 은평구 응암동 94-3',
#   '서울특별시 도봉구 창동 608-204',
#   '서울특별시 강동구 둔촌동 98-43',
#   '서울특별시 강남구 압구정동 397',
#   '서울특별시 금천구 독산동 378-39',
#   '서울특별시 강동구 길동 404-21',
#   '서울특별시 강북구 번동 148-249',
#   '서울특별시 노원구 공릉동 513-50',
#   '서울특별시 은평구 증산동 194-27',
#   '서울특별시 강서구 화곡동 885-1',
#   '서울특별시 동작구 상도동 212-47',
#   '서울특별시 노원구 월계동 270-38',
#   '서울특별시 관악구 신림동 610-213',
#   '서울특별시 마포구 신수동 62-56',
#   '서울특별시 중랑구 묵동 244-75',
#   '서울특별시 동대문구 제기동 252',
#   '서울특별시 관악구 신림동 409-132',
#   '서울특별시 중랑구 망우동 163-28',
#   '서울특별시 서대문구 홍은동 265-47',
#   '서울특별시 광진구 중곡동 253-30',
#   '서울특별시 도봉구 쌍문동 75-31',
#   '서울특별시 서초구 서초동 1560-7',
#   '서울특별시 강북구 번동 460-15',
#   '서울특별시 은평구 갈현동 418-17',
#   '서울특별시 서대문구 북가좌동 3-143',
#   '서울특별시 관악구 신림동 1570-28',
#   '서울특별시 영등포구 대림동 990-34',
#   '서울특별시 서초구 방배동 846-1',
#   '서울특별시 강남구 삼성동 48',
#   '서울특별시 영등포구 문래동2가 35',
#   '서울특별시 마포구 합정동 443-3',
#   '서울특별시 강동구 둔촌동 83-7',
#   '서울특별시 광진구 중곡동 230-11',
#   '서울특별시 동작구 상도동 279-23',
#   '서울특별시 은평구 응암동 756-4',
#   '서울특별시 금천구 독산동 994-75',
#   '서울특별시 강서구 화곡동 472-17',
#   '서울특별시 양천구 목동 803-2',
#   '서울특별시 중랑구 묵동 247-92',
#   '서울특별시 중랑구 중화동 29-3',
#   '서울특별시 은평구 불광동 230-23',
#   '서울특별시 관악구 신림동 598-142',
#   '서울특별시 광진구 구의동 218-29',
#   '서울특별시 은평구 녹번동 35-61',
#   '서울특별시 양천구 신정동 891-1',
#   '서울특별시 동대문구 용두동 785',
#   '서울특별시 은평구 역촌동 23-13',
#   '서울특별시 송파구 방이동 166-10',
#   '서울특별시 양천구 신월동 29-22',
#   '서울특별시 양천구 목동 718-16',
#   '서울특별시 중랑구 상봉동 119-22',
#   '서울특별시 관악구 신림동 409-322',
#   '서울특별시 금천구 독산동 149-13',
#   '서울특별시 송파구 송파동 117-36',
#   '서울특별시 강북구 수유동 279-74',
#   '서울특별시 광진구 중곡동 296-1',
#   '서울특별시 중랑구 중화동 208-4',
#   '서울특별시 서초구 잠원동 31-15',
#   '서울특별시 성북구 정릉동 254-95',
#   '서울특별시 금천구 시흥동 943-23',
#   '서울특별시 구로구 개봉동 367-13',
#   '서울특별시 중구 신당동 67-302',
#   '서울특별시 양천구 신월동 107-34',
#   '서울특별시 강서구 마곡동 12-1',
#   '서울특별시 강서구 화곡동 61-21',
#   '서울특별시 강서구 화곡동 467-16',
#   '서울특별시 은평구 갈현동 327-112',
#   '서울특별시 구로구 구로동 97-10',
#   '서울특별시 성동구 금호동2가 508-2',
#   '서울특별시 구로구 고척동 274-13',
#   '서울특별시 강서구 화곡동 410-38',
#   '서울특별시 동대문구 휘경동 286-109',
#   '서울특별시 양천구 신월동 140-15',
#   '서울특별시 성북구 정릉동 506-10',
#   '서울특별시 도봉구 창동 674-56',
#   '서울특별시 마포구 성산동 165-107',
#   '서울특별시 서대문구 홍제동 136-9',
#   '서울특별시 강북구 수유동 335-13',
#   '서울특별시 은평구 갈현동 288-83',
#   '서울특별시 서초구 방배동 539-174',
#   '서울특별시 서초구 양재동 386-4',
#   '서울특별시 영등포구 영등포동6가 30-5',
#   '서울특별시 양천구 목동 526-14',
#   '서울특별시 관악구 남현동 1055-22',
#   '서울특별시 서초구 방배동 725',
#   '서울특별시 도봉구 도봉동 588-6',
#   '서울특별시 강서구 등촌동 568-30',
#   '서울특별시 중랑구 면목동 132-60',
#   '서울특별시 마포구 상수동 141-1',
#   '서울특별시 동대문구 용두동 138-41',
#   '서울특별시 영등포구 문래동3가 81',
#   '서울특별시 양천구 목동 521-13',
#   '서울특별시 용산구 갈월동 22',
#   '서울특별시 광진구 자양동 665-17',
#   '서울특별시 용산구 청파동2가 60-17',
#   '서울특별시 광진구 자양동 648-29',
#   '서울특별시 송파구 거여동 127-26',
#   '서울특별시 관악구 봉천동 940-17',
#   '서울특별시 강서구 화곡동 394-11',
#   '서울특별시 중랑구 면목동 456-48',
#   '서울특별시 은평구 갈현동 327-100',
#   '서울특별시 중랑구 묵동 247-94',
#   '서울특별시 성북구 장위동 224-17',
#   '서울특별시 강동구 성내동 46-23',
#   '서울특별시 마포구 대흥동 500-6',
#   '서울특별시 도봉구 창동 817',
#   '서울특별시 성북구 정릉동 508-19',
#   '서울특별시 도봉구 방학동 530',
#   '서울특별시 강북구 우이동 155-1',
#   '서울특별시 도봉구 방학동 314-4',
#   '서울특별시 용산구 후암동 334-20',
#   '서울특별시 금천구 독산동 896-42',
#   '서울특별시 광진구 화양동 111-35',
#   '서울특별시 송파구 석촌동 247-8',
#   '서울특별시 관악구 신림동 306-51',
#   '서울특별시 마포구 상수동 339-1',
#   '서울특별시 송파구 석촌동 13-3',
#   '서울특별시 동대문구 전농동 155',
#   '서울특별시 성북구 삼선동3가 22',
#   '서울특별시 은평구 역촌동 82-2',
#   '서울특별시 양천구 목동 318-89',
#   '서울특별시 종로구 동숭동 4-90',
#   '서울특별시 광진구 중곡동 571-1',
#   '서울특별시 구로구 구로동 804-4',
#   '서울특별시 관악구 봉천동 41-156',
#   '서울특별시 구로구 개봉동 330-11',
#   '서울특별시 도봉구 도봉동 644',
#   '서울특별시 은평구 역촌동 68-41',
#   '서울특별시 양천구 목동 644-1',
#   '서울특별시 마포구 망원동 384-52',
#   '서울특별시 양천구 신월동 166-12',
#   '서울특별시 영등포구 신길동 95-290',
#   '서울특별시 관악구 봉천동 719-35',
#   '서울특별시 도봉구 방학동 313-36',
#   '서울특별시 강남구 개포동 1172-2',
#   '서울특별시 은평구 응암동 583-42',
#   '서울특별시 용산구 용산동2가 32-12',
#   '서울특별시 서대문구 홍은동 455',
#   '서울특별시 용산구 갈월동 7-171',
#   '서울특별시 강동구 천호동 391-16',
#   '서울특별시 금천구 시흥동 200-4',
#   '서울특별시 은평구 역촌동 19-3',
#   '서울특별시 구로구 오류동 145-97',
#   '서울특별시 송파구 가락동 150-12',
#   '서울특별시 서초구 양재동 265-2',
#   '서울특별시 은평구 갈현동 492-5',
#   '서울특별시 용산구 동빙고동 309-8',
#   '서울특별시 관악구 봉천동 635-64',
#   '서울특별시 성북구 정릉동 227-70',
#   '서울특별시 강남구 역삼동 766-8',
#   '서울특별시 서초구 방배동 1023-7',
#   '서울특별시 금천구 시흥동 945-41',
#   '서울특별시 송파구 삼전동 94-1',
#   '서울특별시 양천구 목동 555-1',
#   '서울특별시 강동구 천호동 317-23',
#   '서울특별시 중랑구 묵동 121-106',
#   '서울특별시 강서구 화곡동 916-6',
#   '서울특별시 강동구 암사동 486-75',
#   '서울특별시 용산구 원효로1가 83-14',
#   '서울특별시 성북구 석관동 199-18',
#   '서울특별시 성북구 정릉동 716-45',
#   '서울특별시 동작구 상도동 126-65',
#   '서울특별시 광진구 구의동 249-34',
#   '서울특별시 관악구 봉천동 41-96',
#   '서울특별시 강북구 수유동 360-1',
#   '서울특별시 관악구 신림동 409-308',
#   '서울특별시 양천구 신월동 75-19',
#   '서울특별시 서대문구 북가좌동 337-30',
#   '서울특별시 은평구 신사동 300-42',
#   '서울특별시 동대문구 제기동 149-12',
#   '서울특별시 서초구 방배동 781-28',
#   '서울특별시 강남구 역삼동 794-14',
#   '서울특별시 강북구 미아동 129-28',
#   '서울특별시 강북구 미아동 413-1',
#   '서울특별시 은평구 대조동 200-12',
#   '서울특별시 송파구 문정동 89-6',
#   '서울특별시 서초구 양재동 207-5',
#   '서울특별시 은평구 신사동 270-53',
#   '서울특별시 강서구 화곡동 936-1',
#   '서울특별시 구로구 온수동 68',
#   '서울특별시 관악구 신림동 1726',
#   '서울특별시 종로구 인의동 48-2',
#   '서울특별시 용산구 한남동 568-358',
#   '서울특별시 서초구 방배동 890-30',
#   '서울특별시 은평구 대조동 221-20',
#   '서울특별시 강남구 개포동 1194-1',
#   '서울특별시 노원구 상계동 1386',
#   '서울특별시 용산구 원효로3가 1-55',
#   '서울특별시 관악구 봉천동 635-501',
#   '서울특별시 동작구 노량진동 226-21',
#   '서울특별시 도봉구 도봉동 605-34',
#   '서울특별시 노원구 공릉동 751',
#   '서울특별시 강남구 논현동 136-2',
#   '서울특별시 강서구 등촌동 645-2',
#   '서울특별시 영등포구 신길동 436-25',
#   '서울특별시 은평구 불광동 131-1',
#   '서울특별시 금천구 독산동 921-6',
#   '서울특별시 강서구 화곡동 102-364',
#   '서울특별시 강서구 화곡동 61-118',
#   '서울특별시 송파구 방이동 112-14',
#   '서울특별시 성동구 금호동3가 1344-80',
#   '서울특별시 강동구 길동 53',
#   '서울특별시 성북구 종암동 7-69',
#   '서울특별시 서초구 우면동 6-10',
#   '서울특별시 양천구 신월동 221-11',
#   '서울특별시 강서구 염창동 296',
#   '서울특별시 마포구 연남동 564-18',
#   '서울특별시 마포구 대흥동 660',
#   '서울특별시 은평구 신사동 303-4',
#   '서울특별시 성동구 마장동 834',
#   '서울특별시 노원구 상계동 188-10',
#   '서울특별시 은평구 구산동 6-6',
#   '서울특별시 중랑구 면목동 527-300',
#   '서울특별시 양천구 신월동 923-6',
#   '서울특별시 관악구 신림동 610-225',
#   '서울특별시 금천구 시흥동 1003-3',
#   '서울특별시 은평구 역촌동 184-17',
#   '서울특별시 구로구 구로동 780-48',
#   '서울특별시 송파구 삼전동 170-3',
#   '서울특별시 은평구 신사동 200-14',
#   '서울특별시 구로구 개봉동 179-14',
#   '서울특별시 동작구 사당동 278-86',
#   '서울특별시 노원구 상계동 1381-5',
#   '서울특별시 은평구 갈현동 327-75',
#   '서울특별시 용산구 서계동 115',
#   '서울특별시 강서구 등촌동 365-207',
#   '서울특별시 송파구 석촌동 171-17',
#   '서울특별시 관악구 봉천동 180-533',
#   '서울특별시 도봉구 방학동 690-61',
#   '서울특별시 송파구 삼전동 39',
#   '서울특별시 영등포구 당산동1가 185-9',
#   '서울특별시 노원구 공릉동 420-8',
#   '서울특별시 마포구 당인동 12-27',
#   '서울특별시 서초구 서초동 1492-1',
#   '서울특별시 마포구 동교동 156-2',
#   '서울특별시 서대문구 홍제동 6-135',
#   '서울특별시 도봉구 도봉동 578',
#   '서울특별시 중랑구 면목동 139-55',
#   '서울특별시 종로구 창신동 232',
#   '서울특별시 강북구 번동 443-75',
#   '서울특별시 성북구 정릉동 710-81',
#   '서울특별시 강서구 화곡동 917-1',
#   '서울특별시 양천구 신월동 509-21',
#   '서울특별시 광진구 자양동 230-34',
#   '서울특별시 양천구 신월동 99-11',
#   '서울특별시 성북구 정릉동 402-89',
#   '서울특별시 은평구 역촌동 49-7',
#   '서울특별시 관악구 봉천동 635-385',
#   '서울특별시 도봉구 쌍문동 98-94',
#   '서울특별시 강서구 화곡동 366-27',
#   '서울특별시 양천구 신월동 913-6',
#   '서울특별시 동작구 사당동 1051-16',
#   '서울특별시 구로구 오류동 108-85',
#   '서울특별시 동작구 상도1동 561-4',
#   '서울특별시 구로구 구로동 777-3',
#   '서울특별시 노원구 공릉동 338-29',
#   '서울특별시 은평구 불광동 8-53',
#   '서울특별시 동작구 상도동 279-66',
#   '서울특별시 성북구 석관동 128-17',
#   '서울특별시 도봉구 쌍문동 81-98',
#   '서울특별시 동대문구 전농동 620-27',
#   '서울특별시 마포구 성산동 49-12',
#   '서울특별시 용산구 서빙고동 271-36',
#   '서울특별시 광진구 중곡동 126-23',
#   '서울특별시 강서구 방화동 608-178',
#   '서울특별시 도봉구 쌍문동 137-185',
#   '서울특별시 강서구 화곡동 354-85',
#   '서울특별시 강북구 미아동 258-616',
#   '서울특별시 종로구 행촌동 210-85',
#   '서울특별시 성동구 응봉동 193-134',
#   '서울특별시 강서구 화곡동 451-11',
#   '서울특별시 동대문구 장안동 378-3',
#   '서울특별시 성북구 정릉동 252-133',
#   '서울특별시 성북구 동선동5가 12',
#   '서울특별시 서초구 서초동 1362',
#   '서울특별시 은평구 불광동 245-4',
#   '서울특별시 서초구 잠원동 164',
#   '서울특별시 관악구 신림동 610-199',
#   '서울특별시 서대문구 연희동 520-27',
#   '서울특별시 구로구 구로동 779-24',
#   '서울특별시 양천구 신월동 512-19',
#   '서울특별시 성북구 종암동 125-86',
#   '서울특별시 관악구 신림동 102-47',
#   '서울특별시 용산구 한남동 522-1',
#   ...},
#  43984)

# %%
import requests
import os
from tqdm import tqdm

url = "https://dapi.kakao.com/v2/local/search/address.json"
headers = {"Authorization": f"KakaoAK {os.getenv("KAKAO_API_KEY")}"}
address_to_geo = []
for address_name in tqdm(address_names, desc="Fetching data.."):
    params = {"query": address_name, "analyze_type": "exact"}
    response = requests.get(url, headers=headers, params=params)
    docs = response.json().get("documents")
    if not docs:
        print(f"Error: {response.status_code}, {address_name}")
        continue
    x, y = docs[0].get("x"), docs[0].get("y")
    address_to_geo.append({"address": address_name, "lon": x, "lat": y})
# Out:
# Fetching data..:   2%|▏         | 661/43984 [00:45<43:45, 16.50it/s]
# Error: 200, 서울특별시 동대문구 청량리동 199
# Fetching data..:   3%|▎         | 1267/43984 [01:24<44:06, 16.14it/s]
# Error: 200, 서울특별시 강서구 방화동 1171
# Fetching data..:   3%|▎         | 1323/43984 [01:27<45:02, 15.79it/s]
# Error: 200, 서울특별시 관악구 신림동 1644
# Fetching data..:   6%|▌         | 2441/43984 [02:39<43:32, 15.90it/s]
# Error: 200, 서울특별시 중랑구 신내동 488
# Fetching data..:  10%|▉         | 4247/43984 [04:34<43:13, 15.32it/s]
# Error: 200, 서울특별시 강서구 방화동 597
# Fetching data..:  10%|▉         | 4267/43984 [04:35<43:12, 15.32it/s]
# Error: 200, 서울특별시 동대문구 답십리동 12
# Fetching data..:  10%|█         | 4605/43984 [04:56<42:15, 15.53it/s]
# Error: 200, 서울특별시 서초구 잠원동 52-2
# Fetching data..:  11%|█         | 4787/43984 [05:08<42:38, 15.32it/s]
# Error: 200, 서울특별시 구로구 고척동 97
# Fetching data..:  12%|█▏        | 5293/43984 [05:42<42:12, 15.28it/s]
# Error: 200, 서울특별시 마포구 신공덕동 14
# Fetching data..:  13%|█▎        | 5625/43984 [06:02<40:18, 15.86it/s]
# Error: 200, 서울특별시 서대문구 북아현동 149
# Fetching data..:  15%|█▍        | 6399/43984 [06:52<41:02, 15.26it/s]
# Error: 200, 서울특별시 강동구 길동 375-21
# Fetching data..:  15%|█▌        | 6789/43984 [07:18<40:18, 15.38it/s]
# Error: 200, 서울특별시 중구 입정동 189-1
# Fetching data..:  16%|█▌        | 7053/43984 [07:35<37:41, 16.33it/s]
# Error: 200, 서울특별시 중구 입정동 2-4
# Fetching data..:  16%|█▋        | 7201/43984 [07:45<37:32, 16.33it/s]
# Error: 200, 서울특별시 송파구 거여동 0
# Fetching data..:  17%|█▋        | 7463/43984 [08:01<39:38, 15.36it/s]
# Error: 200, 서울특별시 강서구 화곡동 1027-50
# Fetching data..:  18%|█▊        | 7807/43984 [08:23<39:51, 15.13it/s]
# Error: 200, 서울특별시 강서구 화곡동 829-11
# Fetching data..:  18%|█▊        | 7871/43984 [08:27<39:02, 15.42it/s]
# Error: 200, 서울특별시 중랑구 신내동 386-1
# Fetching data..:  19%|█▉        | 8373/43984 [08:59<39:55, 14.87it/s]
# Error: 200, 서울특별시 강서구 방화동 182-42
# Fetching data..:  21%|██        | 9087/43984 [09:44<37:46, 15.39it/s]
# Error: 200, 서울특별시 강서구 방화동 890
# Fetching data..:  23%|██▎       | 9935/43984 [10:40<34:46, 16.32it/s]
# Error: 200, 서울특별시 강서구 방화동 182-44
# Fetching data..:  23%|██▎       | 10183/43984 [10:56<34:51, 16.16it/s]
# Error: 200, 서울특별시 은평구 수색동 190
# Fetching data..:  24%|██▍       | 10579/43984 [11:21<35:09, 15.84it/s]
# Error: 200, 서울특별시 용산구 효창동 3-250
# Fetching data..:  24%|██▍       | 10741/43984 [11:31<35:23, 15.66it/s]
# Error: 200, 서울특별시 강서구 방화동 187-19
# Fetching data..:  25%|██▌       | 11125/43984 [11:56<35:35, 15.39it/s]
# Error: 200, 서울특별시 강서구 방화동 201-1
# Fetching data..:  26%|██▌       | 11289/43984 [12:06<34:45, 15.68it/s]
# Error: 200, 서울특별시 광진구 자양동 863
# Fetching data..:  27%|██▋       | 12013/43984 [12:54<35:45, 14.90it/s]
# Error: 200, 서울특별시 노원구 상계동 65-23
# Fetching data..:  28%|██▊       | 12215/43984 [13:06<31:20, 16.90it/s]
# Error: 200, 서울특별시 동작구 상도동 65-74
# Fetching data..:  29%|██▉       | 12682/43984 [13:33<29:36, 17.62it/s]
# Error: 200, 서울특별시 강서구 방화동 1454
# Fetching data..:  30%|███       | 13278/43984 [14:10<32:27, 15.77it/s]
# Error: 200, 서울특별시 강서구 방화동 897
# Fetching data..:  31%|███       | 13679/43984 [14:35<33:29, 15.08it/s]
# Error: 200, 서울특별시 강동구 성내동 17-4
# Fetching data..:  33%|███▎      | 14689/43984 [15:41<31:47, 15.36it/s]
# Error: 200, 서울특별시 강서구 방화동 896
# Fetching data..:  34%|███▎      | 14809/43984 [15:49<31:00, 15.68it/s]
# Error: 200, 서울특별시 강서구 방화동 876
# Fetching data..:  36%|███▌      | 15873/43984 [16:57<30:06, 15.56it/s]
# Error: 200, 서울특별시 강서구 방화동 859
# Fetching data..:  36%|███▌      | 15887/43984 [16:58<29:47, 15.72it/s]
# Error: 200, 서울특별시 강서구 가양동 118-1
# Fetching data..:  40%|███▉      | 17451/43984 [18:39<28:44, 15.39it/s]
# Error: 200, 서울특별시 성북구 길음동 508-16
# Fetching data..:  40%|████      | 17633/43984 [18:50<26:53, 16.33it/s]
# Error: 200, 서울특별시 강서구 방화동 1467
# Fetching data..:  42%|████▏     | 18297/43984 [19:32<28:16, 15.14it/s]
# Error: 200, 서울특별시 강서구 방화동 182-16
# Fetching data..:  42%|████▏     | 18405/43984 [19:39<27:10, 15.69it/s]
# Error: 200, 서울특별시 관악구 신림동 28-9
# Fetching data..:  44%|████▍     | 19353/43984 [20:41<26:35, 15.44it/s]
# Error: 200, 서울특별시 은평구 신사동 19-190
# Fetching data..:  45%|████▍     | 19619/43984 [20:58<26:16, 15.45it/s]
# Error: 200, 서울특별시 서대문구 남가좌동 286-1
# Fetching data..:  45%|████▌     | 19889/43984 [21:16<26:25, 15.20it/s]
# Error: 200, 서울특별시 구로구 항동 238
# Fetching data..:  45%|████▌     | 19959/43984 [21:20<24:41, 16.22it/s]
# Error: 200, 서울특별시 성북구 청량리동 949
# Fetching data..:  47%|████▋     | 20509/43984 [21:55<25:44, 15.19it/s]
# Error: 200, 서울특별시 강남구 일원동 611-1
# Fetching data..:  48%|████▊     | 21303/43984 [22:48<23:59, 15.75it/s]
# Error: 200, 서울특별시 강서구 방화동 1181
# Fetching data..:  49%|████▉     | 21769/43984 [23:18<27:33, 13.44it/s]
# Error: 200, 서울특별시 성북구 길음동 498
# Fetching data..:  50%|████▉     | 21989/43984 [23:33<23:28, 15.62it/s]
# Error: 200, 서울특별시 서대문구 홍제동 270-1
# Fetching data..:  51%|█████     | 22527/43984 [24:07<21:51, 16.36it/s]
# Error: 200, 서울특별시 강동구 고덕동 1
# Fetching data..:  52%|█████▏    | 22837/43984 [24:27<23:19, 15.11it/s]
# Error: 200, 서울특별시 강동구 성내동 48-6
# Fetching data..:  53%|█████▎    | 23143/43984 [24:47<22:08, 15.69it/s]
# Error: 200, 서울특별시 송파구 거여동 202
# Fetching data..:  53%|█████▎    | 23163/43984 [24:48<21:36, 16.06it/s]
# Error: 200, 서울특별시 강서구 방화동 863
# Fetching data..:  53%|█████▎    | 23377/43984 [25:02<21:19, 16.10it/s]
# Error: 200, 서울특별시 중랑구 면목동 55-14
# Fetching data..:  53%|█████▎    | 23419/43984 [25:04<20:51, 16.44it/s]
# Error: 200, 서울특별시 강서구 방화동 182-12
# Fetching data..:  55%|█████▍    | 24143/43984 [25:50<21:34, 15.33it/s]
# Error: 200, 서울특별시 은평구 수색동 191
# Fetching data..:  56%|█████▌    | 24525/43984 [26:16<23:35, 13.75it/s]
# Error: 200, 서울특별시 도봉구 쌍문동 69-1
# Fetching data..:  57%|█████▋    | 24879/43984 [26:39<19:33, 16.28it/s]
# Error: 200, 서울특별시 송파구 거여동 234
# Fetching data..:  57%|█████▋    | 25101/43984 [26:53<19:51, 15.85it/s]
# Error: 200, 서울특별시 강서구 방화동 184-44
# Fetching data..:  58%|█████▊    | 25325/43984 [27:08<19:15, 16.15it/s]
# Error: 200, 서울특별시 강서구 방화동 272-52
# Fetching data..:  58%|█████▊    | 25577/43984 [27:25<19:48, 15.49it/s]
# Error: 200, 서울특별시 강동구 둔촌동 633
# Fetching data..:  58%|█████▊    | 25609/43984 [27:27<18:08, 16.88it/s]
# Error: 200, 서울특별시 강서구 방화동 186-3
# Fetching data..:  59%|█████▉    | 25975/43984 [27:49<17:34, 17.08it/s]
# Error: 200, 서울특별시 강남구 율현동 0
# Fetching data..:  59%|█████▉    | 26035/43984 [27:53<18:37, 16.06it/s]
# Error: 200, 서울특별시 노원구 상계동 111-347
# Fetching data..:  60%|█████▉    | 26287/43984 [28:09<19:22, 15.22it/s]
# Error: 200, 서울특별시 강서구 방화동 272-57
# Fetching data..:  61%|██████    | 26831/43984 [28:45<21:06, 13.54it/s]
# Error: 200, 서울특별시 성북구 장위동 173-114
# Fetching data..:  61%|██████    | 26849/43984 [28:46<18:56, 15.07it/s]
# Error: 200, 서울특별시 동작구 사당동 42
# Fetching data..:  61%|██████    | 26857/43984 [28:46<18:46, 15.21it/s]
# Error: 200, 서울특별시 동작구 봉천동 1000
# Fetching data..:  62%|██████▏   | 27215/43984 [29:10<19:44, 14.16it/s]
# Error: 200, 서울특별시 송파구 가락동 129-15
# Fetching data..:  62%|██████▏   | 27363/43984 [29:20<17:52, 15.50it/s]
# Error: 200, 서울특별시 도봉구 도봉동 95
# Fetching data..:  62%|██████▏   | 27443/43984 [29:25<18:12, 15.14it/s]
# Error: 200, 서울특별시 노원구 공릉동 230
# Fetching data..:  63%|██████▎   | 27637/43984 [29:37<17:04, 15.96it/s]
# Error: 200, 서울특별시 강서구 화곡동 172-4
# Error: 200, 서울특별시 강서구 방화동 168-114
# Fetching data..:  65%|██████▍   | 28573/43984 [30:36<16:14, 15.81it/s]
# Error: 200, 서울특별시 관악구 사당동 1152
# Fetching data..:  66%|██████▌   | 28923/43984 [31:06<21:53, 11.47it/s]
# Error: 200, 서울특별시 은평구 증산동 213-20
# Fetching data..:  68%|██████▊   | 29921/43984 [32:15<16:44, 14.00it/s]
# Error: 200, 서울특별시 강동구 천호동 55-10
# Fetching data..:  68%|██████▊   | 29985/43984 [32:19<14:14, 16.37it/s]
# Error: 200, 서울특별시 강서구 방화동 888
# Fetching data..:  70%|██████▉   | 30641/43984 [33:01<14:23, 15.45it/s]
# Error: 200, 서울특별시 성북구 정릉동 87-85
# Fetching data..:  72%|███████▏  | 31536/43984 [33:59<13:08, 15.78it/s]
# Error: 200, 서울특별시 강남구 개포동 138
# Fetching data..:  72%|███████▏  | 31688/43984 [34:08<12:33, 16.32it/s]
# Error: 200, 서울특별시 서대문구 홍제동 270
# Fetching data..:  74%|███████▍  | 32447/43984 [34:58<11:44, 16.37it/s]
# Error: 200, 서울특별시 서초구 신원동 690
# Fetching data..:  74%|███████▍  | 32609/43984 [35:08<12:03, 15.72it/s]
# Error: 200, 서울특별시 광진구 자양동 2-6
# Fetching data..:  75%|███████▍  | 32773/43984 [35:19<12:22, 15.10it/s]
# Error: 200, 서울특별시 강서구 방화동 857
# Fetching data..:  75%|███████▍  | 32835/43984 [35:23<11:36, 16.01it/s]
# Error: 200, 서울특별시 강서구 방화동 883
# Fetching data..:  76%|███████▌  | 33383/43984 [35:56<10:58, 16.09it/s]
# Error: 200, 서울특별시 성동구 금호동1가 280
# Fetching data..:  76%|███████▌  | 33495/43984 [36:03<11:13, 15.58it/s]
# Error: 200, 서울특별시 강서구 방화동 272-5
# Fetching data..:  80%|███████▉  | 35093/43984 [37:44<09:01, 16.43it/s]
# Error: 200, 서울특별시 동대문구 용두동 11-1
# Fetching data..:  80%|████████  | 35219/43984 [37:52<09:09, 15.95it/s]
# Error: 200, 서울특별시 관악구 봉천동 101
# Fetching data..:  81%|████████  | 35473/43984 [38:08<10:04, 14.09it/s]
# Error: 200, 서울특별시 서대문구 북아현동 1-954
# Fetching data..:  81%|████████  | 35671/43984 [38:21<08:28, 16.36it/s]
# Error: 200, 서울특별시 강서구 방화동 1525
# Fetching data..:  83%|████████▎ | 36313/43984 [39:02<08:06, 15.76it/s]
# Error: 200, 서울특별시 강서구 방화동 905
# Fetching data..:  84%|████████▎ | 36775/43984 [39:31<07:18, 16.43it/s]
# Error: 200, 서울특별시 서초구 내곡동 0
# Fetching data..:  84%|████████▍ | 37051/43984 [39:48<07:01, 16.43it/s]
# Error: 200, 서울특별시 서대문구 홍은동 338-5
# Fetching data..:  85%|████████▍ | 37373/43984 [40:08<07:07, 15.48it/s]
# Error: 200, 서울특별시 강서구 방화동 174-8
# Fetching data..:  86%|████████▌ | 37761/43984 [40:33<06:31, 15.89it/s]
# Error: 200, 서울특별시 강남구 대치동 977
# Fetching data..:  86%|████████▋ | 37965/43984 [40:45<05:40, 17.68it/s]
# Error: 200, 서울특별시 강서구 방화동 892
# Fetching data..:  87%|████████▋ | 38137/43984 [40:56<06:10, 15.78it/s]
# Error: 200, 서울특별시 강서구 방화동 1261
# Fetching data..:  87%|████████▋ | 38331/43984 [41:09<06:03, 15.56it/s]
# Error: 200, 서울특별시 강서구 방화동 197-3
# Fetching data..:  88%|████████▊ | 38539/43984 [41:22<06:19, 14.34it/s]
# Error: 200, 서울특별시 강서구 방화동 257-13
# Fetching data..:  89%|████████▊ | 39026/43984 [41:56<05:15, 15.73it/s]
# Error: 200, 서울특별시 강서구 방화동 1252
# Fetching data..:  90%|████████▉ | 39378/43984 [42:17<04:47, 16.03it/s]
# Error: 200, 서울특별시 구로구 개봉동 2-28
# Fetching data..:  90%|████████▉ | 39544/43984 [42:28<04:27, 16.58it/s]
# Error: 200, 서울특별시 구로구 개봉동 2-29
# Fetching data..:  91%|█████████ | 40022/43984 [42:57<04:21, 15.17it/s]
# Error: 200, 서울특별시 동작구 사당동 25-2
# Fetching data..:  92%|█████████▏| 40596/43984 [43:34<04:16, 13.23it/s]
# Error: 200, 서울특별시 강서구 방화동 182-39
# Fetching data..:  93%|█████████▎| 41034/43984 [44:04<03:21, 14.66it/s]
# Error: 200, 서울특별시 강서구 방화동 168-38
# Fetching data..:  93%|█████████▎| 41080/43984 [44:07<03:05, 15.66it/s]
# Error: 200, 서울특별시 구로구 천왕동 0
# Fetching data..:  94%|█████████▍| 41318/43984 [44:23<02:50, 15.64it/s]
# Error: 200, 서울특별시 강서구 가양동 115-6
# Fetching data..:  96%|█████████▌| 42184/43984 [45:21<01:55, 15.57it/s]
# Error: 200, 서울특별시 중구 만리동2가 176-1
# Fetching data..:  97%|█████████▋| 42454/43984 [45:38<01:42, 14.93it/s]
# Error: 200, 서울특별시 은평구 수색동 30-2
# Fetching data..:  97%|█████████▋| 42512/43984 [45:42<01:40, 14.63it/s]
# Error: 200, 서울특별시 강서구 방화동 175-12
# Fetching data..:  98%|█████████▊| 43286/43984 [46:33<00:51, 13.46it/s]
# Error: 200, 서울특별시 강서구 방화동 168-70
# Fetching data..: 100%|██████████| 43984/43984 [47:22<00:00, 15.47it/s]

# %%
import csv

with open("Data/address-to-geo.csv", "w", newline="", encoding="utf-8") as file:
    fieldnames = ["address", "lon", "lat"]
    writer = csv.DictWriter(file, fieldnames, lineterminator="\n")
    writer.writeheader()
    writer.writerows(address_to_geo)
